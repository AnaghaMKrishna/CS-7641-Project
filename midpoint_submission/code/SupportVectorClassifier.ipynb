# %% [markdown]
# ## Exploring the data

# %%
# !ls data
# Out:
# BLCA_gene_exp.csv  GBM_gene_exp.csv   KIRC_gene_exp.csv
# CESC_gene_exp.csv  HNSC_gene_exp.csv  LGG_gene_exp.csv

# %%
# !head data/BLCA_gene_exp.csv | cut -f 1-5 -d,
# Out:
# ,ARHGEF10L,HIF3A,RNF17,RNF10
# TCGA-DK-A6B5-01,0.4117620359741987,-0.3148472342501319,-0.1461397580531456,1.1593856497132908
# TCGA-5N-A9KM-01,-0.6746583576834817,-0.2679812496078634,-0.19720275994022124,1.0863557753657629
# TCGA-BT-A0S7-01,-1.3493745400591655,-0.2332996641802055,-0.19720275994022124,0.0219843732412443
# TCGA-FD-A43Y-01,-1.0507029831702035,-0.34159387294391247,0.18682339500210077,1.0227636684940713
# TCGA-YF-AA3L-01,0.6833352604487828,-0.30331177068307585,-0.04053726051998096,0.5410599210274938
# TCGA-DK-A6B6-01,2.157764202249689,-0.3362737264515328,-0.017858511700927705,-0.6164628181989142
# TCGA-KQ-A41N-01,-0.8404802099790415,-0.2950907020383703,-0.19720275994022124,-0.88898701245783
# TCGA-R3-A69X-01,0.03861393109901789,0.006433151914866945,-0.19720275994022124,-0.34414055183575937
# TCGA-FD-A5BT-01,-0.9283780034358554,3.2485160512666327,-0.19720275994022124,-0.8879428649550184

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import accuracy_score, classification_report, balanced_accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc
from imblearn.over_sampling import SMOTE

# %%
df_list = []
labels = []
for file in os.listdir("data/"):
    if file.endswith('.csv'):
        label = file.split('_')[0]
        labels.append(label)
        
        df = pd.read_csv('data/'+file, index_col=0)
        df['cancer_type'] = label #add a column with cancer type 
        df_list.append(df)
        print(f' Shape of {label} DF: {df.shape}')
# Out:
#  Shape of KIRC DF: (606, 20531)
#  Shape of GBM DF: (518, 12043)
#  Shape of HNSC DF: (566, 20531)
#  Shape of CESC DF: (307, 20531)
#  Shape of LGG DF: (529, 20531)
#  Shape of BLCA DF: (426, 20531)

# %% [markdown]
# We can see there is an imbalance in the data for each type of cancer and GBM has only a little over half the number of genes.

# %% [markdown]
# ## Preprocessing and Exploratory Data Analysis

# %%
df_list[0]
# Out:
#                  ARHGEF10L     HIF3A     RNF17     RNF10     RNF11     RNF13  \
# TCGA-B0-5402-01  -0.613869  3.907610 -0.092480 -0.428222 -0.732195 -0.228208
# TCGA-CJ-4634-01   1.150781  0.451041 -0.092480 -0.582534 -0.153104  0.172521
# TCGA-B0-4828-01   0.450394  0.096415 -0.061711  0.075810 -0.529892 -0.497759
# TCGA-CZ-5452-11   1.397206  0.478936 -0.092480  2.427314  0.385003 -0.140100
# TCGA-B4-5835-01  -1.127536 -0.586795 -0.092480 -0.651031 -2.056976  1.756855
# ...                    ...       ...       ...       ...       ...       ...
# TCGA-BP-4784-01  -0.911786 -0.224480 -0.092480 -0.269673  1.034742 -0.471411
# TCGA-BP-4326-01  -1.441992 -0.208324 -0.092480 -0.091613 -0.022957 -0.549953
# TCGA-BP-5183-01   1.584225 -0.414457 -0.092480 -0.489489 -0.203395  0.055019
# TCGA-CZ-4858-01  -1.771377 -0.572639 -0.092480  1.525178 -0.562746  0.846221
# TCGA-CZ-4865-11   0.096384  0.515202 -0.092480  0.591922  1.272197 -0.046855
#
#                   GTF2IP1      REM1     MTVR2    RTN4RL2  ...     NPY5R  \
# TCGA-B0-5402-01 -1.147002 -0.799435 -0.089858  -0.114388  ...  0.710281
# TCGA-CJ-4634-01  0.046365 -0.227903  0.352889  -0.179009  ... -0.638642
# TCGA-B0-4828-01  1.062191 -0.057001  0.865147  -0.053080  ... -0.635284
# TCGA-CZ-5452-11  0.429928 -0.554670 -0.415514  -0.501084  ...  1.565750
# TCGA-B4-5835-01 -1.152287 -0.954072 -0.415514  -0.575197  ...  1.060696
# ...                   ...       ...       ...        ...  ...       ...
# TCGA-BP-4784-01 -0.849035  2.180480 -0.415514   0.432103  ... -0.102417
# TCGA-BP-4326-01 -0.768373 -0.805816 -0.415514   0.041410  ... -0.415023
# TCGA-BP-5183-01  0.495772 -0.864009  1.162661  -0.454486  ... -0.741576
# TCGA-CZ-4858-01  0.871250 -0.643763 -0.415514  12.008514  ... -0.753964
# TCGA-CZ-4865-11  0.146417 -0.343452 -0.415514  -0.520688  ...  6.140606
#
#                     GNGT2     GNGT1     TULP3      PTRF     BCL6B     GSTK1  \
# TCGA-B0-5402-01 -0.201891  0.153669  0.068967 -0.449808  0.059252 -0.063909
# TCGA-CJ-4634-01  0.265801 -0.645776  0.446156  0.172093  0.519404 -0.683210
# TCGA-B0-4828-01 -0.628036  1.913753  1.137948  0.171959 -0.565262  0.371532
# TCGA-CZ-5452-11 -0.550874 -0.625024 -0.991979 -0.875701 -0.970794 -0.536241
# TCGA-B4-5835-01 -0.711862 -0.377746 -1.412339 -1.560296 -1.259452  1.117531
# ...                   ...       ...       ...       ...       ...       ...
# TCGA-BP-4784-01 -0.350022 -0.117953 -1.002027  1.424825  1.072323 -0.940161
# TCGA-BP-4326-01 -0.834493  0.422114 -0.586836  0.119022  1.166012 -0.985150
# TCGA-BP-5183-01  0.427264 -0.135147  1.441242 -0.379014 -0.635599  0.727452
# TCGA-CZ-4858-01  0.472820 -0.645776 -0.690071 -0.522503 -1.033333 -0.434594
# TCGA-CZ-4865-11 -0.515502 -0.645776 -1.202613 -0.417351 -0.931854 -0.650174
#
#                      SELP      SELS  cancer_type
# TCGA-B0-5402-01  0.328185  1.578171         KIRC
# TCGA-CJ-4634-01 -0.652565 -0.989972         KIRC
# TCGA-B0-4828-01 -0.924489 -0.475239         KIRC
# TCGA-CZ-5452-11  2.851699 -0.766554         KIRC
# TCGA-B4-5835-01 -0.983725  0.465267         KIRC
# ...                   ...       ...          ...
# TCGA-BP-4784-01  1.250041  0.313779         KIRC
# TCGA-BP-4326-01  0.526397  0.673991         KIRC
# TCGA-BP-5183-01 -0.312704 -0.667787         KIRC
# TCGA-CZ-4858-01 -1.191037  0.514227         KIRC
# TCGA-CZ-4865-11  4.331516 -0.386380         KIRC
#
# [606 rows x 20531 columns]

# %%
labels
# Out:
# ['KIRC', 'GBM', 'HNSC', 'CESC', 'LGG', 'BLCA']

# %% [markdown]
# Data is z-score normalized as given in the data description.

# %%
summary_stats = df_list[0].describe()
summary_stats
# Out:
#           ARHGEF10L         HIF3A         RNF17         RNF10         RNF11  \
# count  6.060000e+02  6.060000e+02  6.060000e+02  6.060000e+02  6.060000e+02
# mean  -3.363646e-16  1.450985e-16  4.909897e-17 -4.821959e-16 -3.810666e-17
# std    1.000826e+00  1.000826e+00  1.000826e+00  1.000826e+00  1.000826e+00
# min   -2.271841e+00 -6.459548e-01 -9.247980e-02 -2.190582e+00 -2.056976e+00
# 25%   -7.027435e-01 -4.575381e-01 -9.247980e-02 -6.754477e-01 -5.682449e-01
# 50%   -9.518621e-02 -2.597806e-01 -9.247980e-02 -3.054048e-01 -6.842138e-02
# 75%    5.649278e-01  7.352843e-02 -9.247980e-02  5.235957e-01  4.274360e-01
# max    4.285713e+00  1.368242e+01  2.190922e+01  4.721814e+00  9.226470e+00
#
#               RNF13       GTF2IP1          REM1         MTVR2       RTN4RL2  \
# count  6.060000e+02  6.060000e+02  6.060000e+02  6.060000e+02  6.060000e+02
# mean   1.612205e-16  2.447620e-16  8.500718e-17  9.526666e-17  5.276307e-17
# std    1.000826e+00  1.000826e+00  1.000826e+00  1.000826e+00  1.000826e+00
# min   -2.030416e+00 -2.086317e+00 -1.005313e+00 -4.155136e-01 -6.760830e-01
# 25%   -4.740825e-01 -6.878786e-01 -5.919980e-01 -4.155136e-01 -4.016968e-01
# 50%   -1.195395e-01 -1.766619e-01 -2.630672e-01 -4.155136e-01 -1.963531e-01
# 75%    2.913072e-01  4.532590e-01  2.736034e-01  7.958369e-02  8.744978e-02
# max    1.559750e+01  5.427266e+00  9.744529e+00  1.440080e+01  1.212609e+01
#
#        ...         TULP2         NPY5R         GNGT2         GNGT1  \
# count  ...  6.060000e+02  6.060000e+02  6.060000e+02  6.060000e+02
# mean   ...  4.396923e-17 -2.345026e-17  3.136472e-16 -3.810666e-17
# std    ...  1.000826e+00  1.000826e+00  1.000826e+00  1.000826e+00
# min    ... -1.694140e-01 -7.690484e-01 -1.596052e+00 -6.457763e-01
# 25%    ... -1.694140e-01 -6.027938e-01 -6.125888e-01 -6.170579e-01
# 50%    ... -9.174044e-02 -4.101084e-01 -1.220995e-01 -4.023013e-01
# 75%    ...  1.727251e-02  1.682409e-01  4.138173e-01  2.877428e-01
# max    ...  2.424242e+01  6.140606e+00  1.228388e+01  7.780909e+00
#
#               TULP3          PTRF         BCL6B         GSTK1          SELP  \
# count  6.060000e+02  6.060000e+02  6.060000e+02  6.060000e+02  6.060000e+02
# mean   9.966359e-17 -3.429600e-16  5.569436e-17 -1.612205e-16  4.250359e-17
# std    1.000826e+00  1.000826e+00  1.000826e+00  1.000826e+00  1.000826e+00
# min   -2.795868e+00 -1.682022e+00 -1.350690e+00 -1.571467e+00 -1.218395e+00
# 25%   -6.141036e-01 -5.690006e-01 -7.199150e-01 -5.737941e-01 -7.123843e-01
# 50%   -9.582614e-02 -1.310739e-01 -2.016797e-01 -2.477684e-01 -2.511274e-01
# 75%    4.811325e-01  3.894406e-01  4.977574e-01  3.326876e-01  4.466715e-01
# max    6.843142e+00  1.259812e+01  5.835310e+00  1.267937e+01  4.943308e+00
#
#                SELS
# count  6.060000e+02
# mean  -3.253723e-16
# std    1.000826e+00
# min   -1.563071e+00
# 25%   -5.713355e-01
# 50%   -1.768746e-01
# 75%    3.579711e-01
# max    1.270433e+01
#
# [8 rows x 20530 columns]

# %% [markdown]
# We see the means are very close to zero and SD = 1

# %% [markdown]
# ### Merging datasets to get a global view of the data
#
# We merge the datasets based on common features present in all the datasets - intersecting genes

# %%
#find intersecting genes
common_genes = set(df_list[0].columns)
for df in df_list[1:]:
    common_genes &= set(df.columns)

# %%
common_genes
# Out:
# {'KCNK2',
#  'WDR73',
#  'C14orf106',
#  'SLC22A18AS',
#  'KLHL11',
#  'UBE2G2',
#  'BFSP1',
#  'LIPG',
#  'PSMD2',
#  'POFUT1',
#  'TYRP1',
#  'SNTB2',
#  'HN1L',
#  'PAX8',
#  'CHCHD2',
#  'SLC7A2',
#  'ATP5B',
#  'BCAM',
#  'NTRK1',
#  'KCNJ6',
#  'TDG',
#  'GALNT8',
#  'HIST1H3D',
#  'UTP14A',
#  'PCNXL2',
#  'MEPCE',
#  'RYK',
#  'STATH',
#  'N4BP3',
#  'TMEM38B',
#  'GDAP1',
#  'ADRA1B',
#  'POU4F1',
#  'PSAP',
#  'ZNF544',
#  'SYNJ1',
#  'E2F3',
#  'OTOF',
#  'TNFAIP1',
#  'CTLA4',
#  'FZD9',
#  'RS1',
#  'CTBS',
#  'KALRN',
#  'UBIAD1',
#  'FRYL',
#  'ATP6V1F',
#  'RMND1',
#  'PCYT1B',
#  'MAST2',
#  'FBXL7',
#  'RALA',
#  'TMEM140',
#  'SH2D1A',
#  'DDX24',
#  'BAIAP2',
#  'FRAS1',
#  'TNNC2',
#  'LRRC2',
#  'ERCC8',
#  'PTPRS',
#  'CLEC16A',
#  'SLC5A6',
#  'HGSNAT',
#  'CRYZ',
#  'NUPL2',
#  'MEF2A',
#  'COX6B1',
#  'DDR1',
#  'DERL2',
#  'CTNNBL1',
#  'MED13',
#  'PDGFRL',
#  'LARP1',
#  'GNRH1',
#  'TRIM5',
#  'UNC93A',
#  'RNASET2',
#  'PPP4R2',
#  'HPSE2',
#  'PART1',
#  'RBM4B',
#  'IL6ST',
#  'NBN',
#  'NEB',
#  'MPHOSPH9',
#  'LTA',
#  'MAP4K3',
#  'SELL',
#  'ZNF592',
#  'C1QA',
#  'TBC1D15',
#  'FAM131A',
#  'SEC14L5',
#  'ZFP30',
#  'GBP1',
#  'PARP12',
#  'GNAI3',
#  'CAMP',
#  'IL1B',
#  'OSBPL9',
#  'BARD1',
#  'DCN',
#  'FBXW7',
#  'DYNC1H1',
#  'CADM1',
#  'MICB',
#  'PTPRB',
#  'RQCD1',
#  'CEACAM21',
#  'GLIPR1',
#  'SERPINA3',
#  'ARHGAP24',
#  'FAM53B',
#  'KLK6',
#  'NPY2R',
#  'SSX5',
#  'IL18R1',
#  'GNG11',
#  'CD207',
#  'TUBB',
#  'ADORA1',
#  'INS',
#  'ADD1',
#  'CD47',
#  'CEP164',
#  'FRG1',
#  'HTR7',
#  'KLHL24',
#  'RYR3',
#  'CRYBA4',
#  'KCNG1',
#  'MDK',
#  'CHPT1',
#  'MXD4',
#  'SF1',
#  'KCNN4',
#  'SAE1',
#  'KCNQ4',
#  'MLF2',
#  'PTPRT',
#  'CCKAR',
#  'ATP5D',
#  'IPO9',
#  'RAD54L',
#  'CBX4',
#  'LIPE',
#  'NPHP4',
#  'ARL4C',
#  'PAPPA',
#  'MADCAM1',
#  'C3orf52',
#  'CXCL10',
#  'RPS3A',
#  'ATR',
#  'C13orf27',
#  'BTBD3',
#  'AMPH',
#  'TBC1D9',
#  'CFHR2',
#  'CA6',
#  'SOX2',
#  'ITM2B',
#  'RAB33B',
#  'DOCK10',
#  'RPL18',
#  'IDH3A',
#  'ZNF451',
#  'AARS',
#  'TUBAL3',
#  'QARS',
#  'PSAT1',
#  'ARNTL',
#  'MYBBP1A',
#  'RAC3',
#  'EMD',
#  'OPN1SW',
#  'CIDEA',
#  'FOXP3',
#  'HPX',
#  'GAN',
#  'COQ3',
#  'MUM1',
#  'MTMR14',
#  'NT5M',
#  'GCM1',
#  'ZNF365',
#  'GSPT1',
#  'LILRA5',
#  'CD7',
#  'EEF1A2',
#  'ATP6V1E1',
#  'MYBL1',
#  'HIST1H2BO',
#  'CDS1',
#  'FOXH1',
#  'CASP6',
#  'LGALS3',
#  'CTAGE1',
#  'GPR6',
#  'OR12D2',
#  'THYN1',
#  'COLQ',
#  'SNX2',
#  'CAB39L',
#  'RPL9',
#  'TMEM147',
#  'SPHK1',
#  'SYK',
#  'ISLR',
#  'RRAGD',
#  'CHD5',
#  'MGC3771',
#  'FLT3LG',
#  'SLC10A1',
#  'DEFB126',
#  'BPI',
#  'TREX1',
#  'NPAS1',
#  'EXTL2',
#  'USP21',
#  'SLC22A3',
#  'LAMB3',
#  'TFAP2A',
#  'AFF1',
#  'PUM2',
#  'C5orf23',
#  'DEAF1',
#  'C22orf31',
#  'SHC3',
#  'PDS5B',
#  'RAF1',
#  'USH2A',
#  'BFSP2',
#  'GOSR2',
#  'DLX5',
#  'ELMO3',
#  'MCM3AP',
#  'CST3',
#  'LY6H',
#  'FAM38A',
#  'TTLL12',
#  'PFDN6',
#  'IQCB1',
#  'DDAH1',
#  'TLE2',
#  'RTN3',
#  'SIM2',
#  'SLC39A4',
#  'DDX56',
#  'EIF1B',
#  'BOP1',
#  'STEAP3',
#  'BMP7',
#  'ARID3B',
#  'SPIB',
#  'COL15A1',
#  'EPN3',
#  'HSPB2',
#  'MEOX1',
#  'SETD2',
#  'TFDP1',
#  'IMPDH2',
#  'ALDH2',
#  'NIT1',
#  'IFNA8',
#  'ETV6',
#  'GRB2',
#  'FLT1',
#  'LGALS3BP',
#  'DAK',
#  'SIRT6',
#  'SLC11A2',
#  'ZFR',
#  'CLK3',
#  'PARVB',
#  'HKDC1',
#  'COL14A1',
#  'ABCD2',
#  'APBB1',
#  'CSNK1G2',
#  'PFKL',
#  'TRAM1',
#  'GMIP',
#  'LPHN3',
#  'HPS6',
#  'ZNF212',
#  'ARHGEF18',
#  'CYP7A1',
#  'GRK5',
#  'PF4V1',
#  'SRD5A2',
#  'PALM',
#  'RASGRP2',
#  'CYLC2',
#  'R3HDM2',
#  'ATF6',
#  'KIAA0513',
#  'SERPINA5',
#  'ORC6L',
#  'BTNL8',
#  'MPP5',
#  'KRR1',
#  'MUS81',
#  'MMP28',
#  'GRLF1',
#  'GPER',
#  'NPTX1',
#  'PSMA2',
#  'FKBP8',
#  'NFIX',
#  'SLC25A13',
#  'MYO1C',
#  'AUH',
#  'GCNT2',
#  'MIF',
#  'IL18',
#  'DOM3Z',
#  'CAMSAP1',
#  'FZD8',
#  'OR7A17',
#  'SLCO4C1',
#  'RHOC',
#  'KLHL21',
#  'HIST1H4H',
#  'BRCA2',
#  'DPF2',
#  'IGF2R',
#  'NOX3',
#  'HOXC6',
#  'GRM6',
#  'OSBPL11',
#  'NAT9',
#  'PIK3R1',
#  'IRS1',
#  'GADD45G',
#  'ZEB2',
#  'STAB1',
#  'TMEM176A',
#  'SLC25A12',
#  'ETNK1',
#  'BCHE',
#  'MSH2',
#  'KLRB1',
#  'IRF9',
#  'CUZD1',
#  'UNC119B',
#  'ZNF8',
#  'DRD2',
#  'ANXA7',
#  'E4F1',
#  'PHF15',
#  'TEX264',
#  'ATP1B4',
#  'DULLARD',
#  'KCNJ15',
#  'ADAMTS7',
#  'DPP6',
#  'MORC2',
#  'SGK3',
#  'ITGA3',
#  'CCT8L2',
#  'KCNS3',
#  'AFF4',
#  'AMACR',
#  'JRKL',
#  'LRP4',
#  'KLK8',
#  'ADAMTS5',
#  'WWOX',
#  'SPINT2',
#  'CHRD',
#  'GAB1',
#  'FUT7',
#  'C14orf132',
#  'SF3B2',
#  'BMP8A',
#  'GRINA',
#  'CA11',
#  'GATA4',
#  'GTF2E2',
#  'TOX4',
#  'TCTN1',
#  'F13B',
#  'SENP3',
#  'FNBP4',
#  'C16orf53',
#  'SKIV2L',
#  'ANK3',
#  'MRPL35',
#  'CCNB1IP1',
#  'KLF3',
#  'KIF5A',
#  'PPIL2',
#  'SLC25A23',
#  'TTC31',
#  'ACTA1',
#  'DPYSL2',
#  'CHN1',
#  'TOMM20',
#  'PHF17',
#  'VEGFA',
#  'MTUS1',
#  'UCHL3',
#  'NR5A1',
#  'NAV2',
#  'ALOX5AP',
#  'ALX1',
#  'PDE4B',
#  'ELF1',
#  'ELAVL4',
#  'STARD7',
#  'TAT',
#  'PDIA5',
#  'TUBB2C',
#  'PMP22',
#  'IL10',
#  'HLCS',
#  'WDR74',
#  'ABHD5',
#  'SUMO1',
#  'KLK15',
#  'FAHD2A',
#  'ALDH3A1',
#  'ADAM29',
#  'SEC61B',
#  'C6',
#  'TSNAX',
#  'CLIP2',
#  'ZER1',
#  'ADCY8',
#  'CUEDC1',
#  'RNGTT',
#  'PIPOX',
#  'MECR',
#  'C6orf62',
#  'LY6D',
#  'PAICS',
#  'CYP2C8',
#  'ZNF266',
#  'ASB8',
#  'CEACAM5',
#  'BTG3',
#  'CDS2',
#  'TBCD',
#  'ATP5H',
#  'PRKD2',
#  'PGS1',
#  'GSTA4',
#  'GPR31',
#  'ARHGEF10',
#  'GEMIN4',
#  'ARL2BP',
#  'ZNF208',
#  'PAK2',
#  'PRR13',
#  'CD74',
#  'GORASP2',
#  'MKI67',
#  'COL6A1',
#  'RIF1',
#  'MFSD5',
#  'LRRFIP1',
#  'TRIM6-TRIM34',
#  'SAG',
#  'ITPR3',
#  'KBTBD4',
#  'EVC',
#  'DRD4',
#  'ZW10',
#  'GRIN2D',
#  'ACAA1',
#  'RAPGEF1',
#  'EGFL6',
#  'TTLL7',
#  'C20orf195',
#  'BMI1',
#  'PRDX6',
#  'GRM7',
#  'ZNF467',
#  'PROS1',
#  'RAB2A',
#  'CDC14A',
#  'ERO1LB',
#  'MED25',
#  'PTK2B',
#  'CCT2',
#  'SLC6A3',
#  'LTBP1',
#  'LAPTM5',
#  'CACNA2D1',
#  'GRIK1',
#  'ECT2',
#  'BGLAP',
#  'NUAK2',
#  'JMJD4',
#  'EXOC7',
#  'CDH20',
#  'PRKAA1',
#  'CDH15',
#  'POU6F1',
#  'CNTNAP2',
#  'PML',
#  'CRNKL1',
#  'P4HB',
#  'WNK1',
#  'OR10J1',
#  'TEAD4',
#  'CAPRIN2',
#  'RFTN1',
#  'GNL3L',
#  'RANGAP1',
#  'BRCA1',
#  'SNX3',
#  'AMOT',
#  'SEC14L3',
#  'SPTBN2',
#  'ZNF185',
#  'ANKRD55',
#  'SCRG1',
#  'IFI16',
#  'SIPA1L3',
#  'KCNB1',
#  'PPP1R2P9',
#  'NFX1',
#  'STARD13',
#  'C14orf115',
#  'PMS2L5',
#  'SLC9A7',
#  'PRCC',
#  'ANGEL1',
#  'PPFIA1',
#  'GLUD2',
#  'LYVE1',
#  'KIAA0753',
#  'CYLD',
#  'KCNK15',
#  'CHL1',
#  'COPB1',
#  'JDP2',
#  'CEND1',
#  'TIMM9',
#  'STXBP6',
#  'ZBTB17',
#  'MAPK4',
#  'WAS',
#  'POLR1C',
#  'CD53',
#  'ARHGEF9',
#  'C15orf5',
#  'PEMT',
#  'TSPYL2',
#  'SOS2',
#  'CRBN',
#  'PXN',
#  'TMEM97',
#  'STAP1',
#  'PTX3',
#  'MAN1A1',
#  'TYROBP',
#  'MAPRE2',
#  'SRM',
#  'PRKAB1',
#  'XPOT',
#  'QTRT1',
#  'RIBC2',
#  'ARHGEF4',
#  'IL12RB2',
#  'TFF3',
#  'TMEM45A',
#  'S100A8',
#  'CACNA1A',
#  'F3',
#  'KHSRP',
#  'CYP2C9',
#  'NCOA3',
#  'TNFSF11',
#  'ZBTB7C',
#  'HIST2H2BE',
#  'NDOR1',
#  'FOXD1',
#  'LSM4',
#  'TRIP4',
#  'SRBD1',
#  'BUB3',
#  'DCP2',
#  'ATG4A',
#  'GALR3',
#  'CETN3',
#  'ZNF35',
#  'PCTP',
#  'TIPRL',
#  'ARL4D',
#  'DNTT',
#  'HAGH',
#  'VAMP4',
#  'ATP5G2',
#  'NOC4L',
#  'TAGLN',
#  'ADAM5P',
#  'TIMM17A',
#  'RPL5',
#  'TRPV5',
#  'DUSP6',
#  'BCL3',
#  'IMPDH1',
#  'HIST1H4A',
#  'DPM1',
#  'CBR1',
#  'MS4A3',
#  'CEACAM8',
#  'TRIB1',
#  'PLA2G7',
#  'PDCD6IP',
#  'TUBA3C',
#  'PEX5',
#  'RHOBTB3',
#  'ABAT',
#  'DIO2',
#  'RABEP2',
#  'MTMR11',
#  'ABCE1',
#  'RUNX3',
#  'TNFRSF8',
#  'ENOX1',
#  'MAP3K6',
#  'MYB',
#  'C16orf58',
#  'COX5B',
#  'DYNLL1',
#  'CRIPT',
#  'MCAT',
#  'GOLGA1',
#  'BBS4',
#  'NDUFS7',
#  'GATAD1',
#  'UROS',
#  'PLA2R1',
#  'GUF1',
#  'GAPVD1',
#  'ZDHHC18',
#  'DHDDS',
#  'RHOB',
#  'SNRPN',
#  'POLE2',
#  'CCDC130',
#  'C4orf31',
#  'PRPF40A',
#  'DVL1',
#  'TOP3B',
#  'CA8',
#  'OBSCN',
#  'IGHMBP2',
#  'PAPOLA',
#  'C4BPA',
#  'TAS2R10',
#  'PLEKHM2',
#  'GLRA3',
#  'THBS4',
#  'NAIP',
#  'CLCNKB',
#  'ULK1',
#  'PPP2R3C',
#  'TSC22D1',
#  'OLFML2B',
#  'LCP1',
#  'EIF4EBP2',
#  'CDKN3',
#  'VPS33B',
#  'HAT1',
#  'RBM19',
#  'BRSK2',
#  'RHOT2',
#  'SCO2',
#  'SLC25A36',
#  'MRPL16',
#  'CHRNA4',
#  'ZFAND1',
#  'C20orf30',
#  'CAPN9',
#  'CTSL1',
#  'EPHX2',
#  'PDE11A',
#  'GRRP1',
#  'SHB',
#  'ATP6V1A',
#  'CARTPT',
#  'REEP1',
#  'PDCD10',
#  'CTPS2',
#  'MTERFD2',
#  'ZNF408',
#  'SLC6A2',
#  'HSPB6',
#  'ENPEP',
#  'SCAMP2',
#  'PPP2R2B',
#  'TAS2R16',
#  'ATAD2B',
#  'CPNE3',
#  'GP1BA',
#  'GRAP',
#  'TFAP2C',
#  'RARRES2',
#  'FGB',
#  'HIST1H2BB',
#  'SEC31A',
#  'SSX3',
#  'PIGB',
#  'PRSS22',
#  'CAPN2',
#  'LCT',
#  'LYRM5',
#  'THAP10',
#  'MEF2D',
#  'POLQ',
#  'RPP14',
#  'RASSF2',
#  'TMEM159',
#  'PHB',
#  'TMPRSS2',
#  'LYRM4',
#  'MKRN1',
#  'ARSD',
#  'CETN1',
#  'PSMB2',
#  'C18orf25',
#  'UXT',
#  'RAD52',
#  'PTGDS',
#  'GCDH',
#  'MCF2L',
#  'MS4A12',
#  'TTC1',
#  'THAP4',
#  'RPS20',
#  'BCKDHB',
#  'DPH5',
#  'BPGM',
#  'PCID2',
#  'ZSCAN12',
#  'SLC12A7',
#  'CCDC94',
#  'PDCD6',
#  'STYXL1',
#  'TRHR',
#  'TMEM109',
#  'GPX3',
#  'ALDH3B2',
#  'HADHA',
#  'KCNK5',
#  'FTSJ1',
#  'SIP1',
#  'COMMD3',
#  'DUSP21',
#  'ZNF107',
#  'PCM1',
#  'KRT3',
#  'DHX34',
#  'HOXA2',
#  'APOOL',
#  'GTF2H5',
#  'OR10C1',
#  'EPN2',
#  'PTPRH',
#  'GBA3',
#  'FLJ10213',
#  'PKN2',
#  'SELT',
#  'NMBR',
#  'COX4NB',
#  'LRP1',
#  'MAPK8',
#  'PDGFC',
#  'GFI1B',
#  'COL8A2',
#  'ZNF444',
#  'SORBS2',
#  'MFSD7',
#  'VSX1',
#  'MYO3A',
#  'KCTD13',
#  'TRPA1',
#  'SF3B1',
#  'PLD3',
#  'CDH17',
#  'SETBP1',
#  'TIMP3',
#  'OLAH',
#  'NT5DC3',
#  'SETMAR',
#  'TRAPPC6A',
#  'PHF7',
#  'F2R',
#  'MIA',
#  'UBE2E3',
#  'VPS41',
#  'SLC35D2',
#  'INTS12',
#  'LHX2',
#  'AGRN',
#  'ZMIZ1',
#  'AVEN',
#  'BMPR1A',
#  'CASC3',
#  'SYNCRIP',
#  'SEZ6L2',
#  'PDE4DIP',
#  'MED21',
#  'TNC',
#  'DLG1',
#  'TIMM10',
#  'YTHDF3',
#  'GABRB2',
#  'BCAP31',
#  'VARS',
#  'ELAVL3',
#  'TSSC4',
#  'DUSP4',
#  'CLIP1',
#  'DUT',
#  'FKBP14',
#  'C1orf9',
#  'TEKT2',
#  'PAFAH1B3',
#  'ATP4B',
#  'EIF2C4',
#  'ELOVL1',
#  'NUP107',
#  'KRAS',
#  'LILRA2',
#  'NXT2',
#  'CDO1',
#  'DDX49',
#  'MIS12',
#  'CREBL2',
#  'PLP1',
#  'ADAM28',
#  'PGM5',
#  'SPINK4',
#  'ADORA3',
#  'GH1',
#  'DYRK4',
#  'MOBP',
#  'FXR2',
#  'IL7',
#  'SESN1',
#  'NDUFA10',
#  'PEX11B',
#  'F11R',
#  'TIMM44',
#  'KIF1B',
#  'CSF2',
#  'HRC',
#  'RB1',
#  'RTCD1',
#  'TNS4',
#  'ZDHHC14',
#  'VAX2',
#  'CACNA1E',
#  'MAFF',
#  'CHMP4A',
#  'GMPPA',
#  'CCDC47',
#  'ZNF395',
#  'CTDP1',
#  'HHLA1',
#  'IPO4',
#  'RUNDC3A',
#  'SMAD7',
#  'UMOD',
#  'EGLN3',
#  'GRIN2C',
#  'SRR',
#  'ZNF197',
#  'CAPN11',
#  'PPIC',
#  'ATAD3A',
#  'FSCN3',
#  'DDX39',
#  'FAM119B',
#  'VPS24',
#  'PRG4',
#  'RALY',
#  'C20orf11',
#  'LSM1',
#  'NOL7',
#  'CXorf36',
#  'HAX1',
#  'SLC11A1',
#  'SLC4A5',
#  'PRDX4',
#  'GAGE1',
#  'MDFI',
#  'UCP1',
#  'ATRX',
#  'USP22',
#  'NOTCH1',
#  'GKN1',
#  'MARK2',
#  'LRRC20',
#  'CDT1',
#  'HN1',
#  'MARCH5',
#  'PCOLCE2',
#  'USPL1',
#  'COL6A3',
#  'ARMCX6',
#  'RPP30',
#  'C17orf80',
#  'MYL1',
#  'RNF121',
#  'MAZ',
#  'CADM3',
#  'FABP4',
#  'TBC1D5',
#  'SLC26A10',
#  'LHX3',
#  'FMO1',
#  'SCD5',
#  'TXNL4B',
#  'GMPR2',
#  'RFX2',
#  'ZMYM1',
#  'NTAN1',
#  'CAPN7',
#  'POLR3E',
#  'ANKRD40',
#  'NQO2',
#  'CRELD1',
#  'CCDC144A',
#  'COG5',
#  'MARCH2',
#  'TRAIP',
#  'TROVE2',
#  'RAE1',
#  'MTRR',
#  'SFTPB',
#  'TRMU',
#  'CLEC4M',
#  'NR2F2',
#  'PCLO',
#  'APPL1',
#  'DOPEY1',
#  'PALLD',
#  'USP34',
#  'MAP6D1',
#  'TAX1BP3',
#  'DBT',
#  'PCDHGA11',
#  'BOLA1',
#  'ZNF654',
#  'CFI',
#  'UTP3',
#  'ATP5E',
#  'IFIT3',
#  'SH3YL1',
#  'MRPS30',
#  'TFF1',
#  'HOXB6',
#  'CISD1',
#  'ERCC2',
#  'ELF5',
#  'ZBTB32',
#  'ZNF154',
#  'OIP5',
#  'MLC1',
#  'PTPN9',
#  'RBX1',
#  'MCM3APAS',
#  'MICAL2',
#  'RFK',
#  'ITGB3',
#  'DDX31',
#  'LGI2',
#  'EFNA3',
#  'SFMBT1',
#  'ACP2',
#  'LASP1',
#  'ACTL7A',
#  'UBE3C',
#  'CSHL1',
#  'MARCO',
#  'SORBS1',
#  'TMF1',
#  'YTHDC1',
#  'ACSM3',
#  'ZNF193',
#  'C12orf52',
#  'FOXJ2',
#  'MBD4',
#  'GOLPH3',
#  'CSK',
#  'KLF4',
#  'MST1R',
#  'EGLN1',
#  'TXK',
#  'CYP2A13',
#  'C21orf33',
#  'COL9A1',
#  ...}

# %%
len(common_genes)
# Out:
# 11313

# %%
#merge data on common genes
merged_df = pd.concat([df[list(common_genes)] for df in df_list], axis=0)

print(f"Merged Data Shape: {merged_df.shape}")
print(merged_df.head())

#save merged dataframe
merged_df.to_csv("data/merged_counts.csv")
# Out:
# Merged Data Shape: (2952, 11313)
#                     KCNK2     WDR73  C14orf106  SLC22A18AS    KLHL11  \
# TCGA-B0-5402-01 -0.170613  1.027621   0.925343    0.230705  0.984737
# TCGA-CJ-4634-01  1.911965  1.018682   0.091202   -0.363738  1.077494
# TCGA-B0-4828-01  0.726777  2.174053  -1.247898   -0.187991 -0.849603
# TCGA-CZ-5452-11 -0.070975 -0.091419  -0.266658   -0.964694  0.656015
# TCGA-B4-5835-01 -0.535658  0.880160  -0.635417    3.539819  0.405239
#
#                    UBE2G2     BFSP1      LIPG     PSMD2    POFUT1  ...  \
# TCGA-B0-5402-01 -1.583525 -0.585524 -0.275577  0.659863  0.359178  ...
# TCGA-CJ-4634-01 -0.228929 -0.478407 -0.096676 -0.488038 -0.255865  ...
# TCGA-B0-4828-01 -0.175189 -0.797046 -0.209035 -0.461678 -0.050359  ...
# TCGA-CZ-5452-11 -0.638395  1.369067  0.271781  0.241112  0.465234  ...
# TCGA-B4-5835-01 -1.061080 -1.020155 -0.191004  2.621851 -0.503743  ...
#
#                     TCEB2  KIAA0754     HOXD1     SCML1       LCK   TMEM186  \
# TCGA-B0-5402-01 -0.285829  0.205256 -0.762085 -0.021551 -0.522453  0.702209
# TCGA-CJ-4634-01 -0.448309  0.277889 -0.717703 -0.315693 -0.735331 -0.296473
# TCGA-B0-4828-01  0.152980 -0.930551  0.053657  2.318032 -0.111739  0.603341
# TCGA-CZ-5452-11 -0.306524  1.354015  0.008953 -0.609059 -0.379079 -0.108530
# TCGA-B4-5835-01  1.010194 -0.953428 -0.832807  0.027157 -0.560565  4.985484
#
#                  SLC25A21   ANKRD57    PIK3R4   ALDH1B1
# TCGA-B0-5402-01  0.044261 -0.084071  0.534601 -0.308160
# TCGA-CJ-4634-01 -0.065970  0.546530  0.973581 -0.284901
# TCGA-B0-4828-01 -0.023516 -0.510755 -0.769642 -0.519890
# TCGA-CZ-5452-11 -0.003730  0.711227  1.227558 -0.459430
# TCGA-B4-5835-01 -0.151928 -0.933580  2.127771  1.603382
#
# [5 rows x 11313 columns]

# %% [markdown]
# ### Normalization

# %%
#Checking the distribution of merged data
plt.figure(figsize=(8, 6))
sns.histplot(merged_df.loc[:, merged_df.columns != "cancer_type"].values.flatten(), bins=100, kde=True)
plt.title("Distribution of z-score normalized counts data after merging")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - The orginal data is z-score normalized as seen from the above plot, hence no normalization is required.
# - Re-normalization after merging is not required as the data still follows standard normal distribution

# %% [markdown]
# ### Data Imputation

# %%
#check for missing values
merged_df.isna().any()
# Out:
# KCNK2         False
# WDR73         False
# C14orf106     False
# SLC22A18AS    False
# KLHL11        False
#               ...
# TMEM186       False
# SLC25A21      False
# ANKRD57       False
# PIK3R4        False
# ALDH1B1       False
# Length: 11313, dtype: bool

# %%
np.where(merged_df.isna().any())
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# There are no missing values, hence data imputation is not required.

# %% [markdown]
# ### Class rebalancing using SMOTE

# %%
merged_df['cancer_type'].value_counts()
# Out:
# cancer_type
# KIRC    606
# HNSC    566
# LGG     529
# GBM     518
# BLCA    426
# CESC    307
# Name: count, dtype: int64

# %%
samples_before = merged_df['cancer_type'].value_counts()

before_smote = pd.DataFrame({
    "Cancer Type": samples_before.index,
    "Number of Samples": samples_before.values
})

plt.figure(figsize=(8, 6))
sns.barplot(x="Cancer Type", y="Number of Samples", data=before_smote, hue='Cancer Type', palette="viridis")
# Out:
# <Axes: xlabel='Cancer Type', ylabel='Number of Samples'>

# %% [markdown]
# As we can see the classes are very imbalanced with CESC having only 307 datapoints where as KIRC has 606 datapoints. To avoid the model being baised towards over-represented data, we can use SMOTE(Synthetic Minority Oversampling Technique) which synthetically creates datapoints for under-represented classes.

# %%
#separate datapoints and labels
X = merged_df.loc[:, merged_df.columns != "cancer_type"]
y = merged_df["cancer_type"]

# %%
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

X_smote = pd.DataFrame(X_resampled, columns=X.columns)
y_smote = pd.DataFrame(y_resampled, columns=["cancer_type"])

smote_df = pd.concat([X_smote, y_smote], axis=1)

# %%
smote_df['cancer_type'].value_counts()
# Out:
# cancer_type
# KIRC    606
# GBM     606
# HNSC    606
# CESC    606
# LGG     606
# BLCA    606
# Name: count, dtype: int64

# %%
samples_after = smote_df['cancer_type'].value_counts()

after_smote = pd.DataFrame({
    "Cancer Type": samples_after.index,
    "Number of Samples": samples_after.values
})

plt.figure(figsize=(8, 6))
sns.barplot(x="Cancer Type", y="Number of Samples", data=after_smote, hue='Cancer Type', palette="viridis")
# Out:
# <Axes: xlabel='Cancer Type', ylabel='Number of Samples'>

# %% [markdown]
# ### Feature engineering and Dimensionality reduction

# %% [markdown]
# A common step in RNAseq analyses is to find highly variable genes. Typically, the top 1000-10000 highly variable genes are used for downstream analyses. We'll use 5000 highly variable genes.

# %%
top_genes = X_smote.var(axis=0).nlargest(5000).index
X_hvg = X_smote[top_genes]
y_hvg = y_smote.values[:, 0]

# %%
X_hvg
# Out:
#         MAGEB1      FSHR       IL3    CYP3A4    CRYBB3      MYL4     ADRB3  \
# 0    -0.064513 -0.179857 -0.206956 -0.076612 -0.143307 -0.417568 -0.413737
# 1    -0.064513 -0.179857 -0.206956 -0.094389 -0.095009  0.232305 -0.027568
# 2    -0.064513 -0.179857 -0.206956 -0.109060 -0.102317 -0.765819 -0.413737
# 3    -0.064513 -0.046662 -0.206956 -0.114829 -0.144820 -0.877148  0.682419
# 4    -0.064513  0.035158 -0.206956  0.452143 -0.114303 -0.858182 -0.301389
# ...        ...       ...       ...       ...       ...       ...       ...
# 3631 -0.110521 -0.410238  0.888783 -0.066203  0.452282  0.058008 -0.094941
# 3632 -0.110521  2.894941 -0.173352 -0.051397 -0.282620 -0.156171  0.609424
# 3633 -0.110521 -0.410238 -0.173352 -0.067088 -0.543997 -0.058863  0.174306
# 3634 -0.110521 -0.410238 -0.173352 -0.022032  0.646172  0.284504  0.514918
# 3635 -0.110521 -0.410238 -0.173352  0.035586 -0.121703 -0.350481 -0.496329
#
#           PMP2     PAGE1       GK2  ...     NEIL1      TSFM    ELOVL4  \
# 0    -0.262871 -0.042003 -0.199312  ... -0.902053 -0.224649 -0.243452
# 1    -0.262871 -0.042003 -0.199312  ... -0.290985 -0.563237 -0.242351
# 2    -0.262871 -0.042003 -0.199312  ... -0.457714  0.497745 -0.228892
# 3    -0.262871 -0.042003 -0.199312  ... -0.130499  0.596715 -0.334113
# 4    -0.262871 -0.042003 -0.199312  ... -0.943613  1.064943  0.150171
# ...        ...       ...       ...  ...       ...       ...       ...
# 3631  0.231922 -0.132873 -0.440943  ...  1.139843 -0.093472  1.207399
# 3632 -0.543005 -0.132873  0.192979  ... -0.382634 -0.141907  1.902326
# 3633 -0.712574 -0.132873 -0.648575  ...  0.242800 -0.153956  0.273923
# 3634 -0.534226 -0.132873 -0.648575  ... -0.111786  0.948557 -0.154386
# 3635 -0.644098 -0.132873 -0.267852  ... -0.921390 -0.125395 -0.389991
#
#         PTGER4      RBP3     PDGFC     GNB1L      FMR1     EMID1  C14orf135
# 0    -0.802696 -0.285669 -0.005129 -0.563166 -0.167055  0.378669   0.145343
# 1    -0.852675 -0.285669  0.678899 -0.710237 -0.641696 -0.478930   0.163877
# 2    -0.792896 -0.285669 -0.490260 -0.219128  0.274402 -0.390020   0.011180
# 3     0.058060 -0.285669 -0.720228 -0.142494  0.067793 -0.743749   0.666000
# 4    -0.947218  0.178635 -0.131974  0.155132  1.908157 -0.351933   0.043072
# ...        ...       ...       ...       ...       ...       ...        ...
# 3631  0.037717 -0.251555 -0.336317 -0.191758 -0.475333  0.432852  -1.220784
# 3632 -0.392515  0.100807  0.867928 -0.966612  0.587243 -0.424883   0.046218
# 3633 -0.521982  0.530053  0.215228 -0.660904  0.564724 -0.261889   0.840391
# 3634  0.975151 -0.673189  0.177186  2.155424 -1.357120  1.930229  -0.584499
# 3635  0.424801  0.761540  1.008253  0.150397 -0.861827 -0.644204  -0.270531
#
# [3636 rows x 5000 columns]

# %% [markdown]
# ##### Applying PCA for dimensionality reduction

# %%
pca = PCA(n_components=50)
X_pca = pca.fit_transform(X_hvg)

pca_df = pd.DataFrame(X_pca[:, :2], columns=["PC1", "PC2"])
pca_df["cancer_type"] = smote_df["cancer_type"].values

# %%
#checking the variance explained by each PC
pca.explained_variance_ratio_
# Out:
# array([0.0921476 , 0.04334929, 0.03945803, 0.03540436, 0.02964184,
#        0.02383108, 0.02137417, 0.02018638, 0.01620336, 0.0149556 ,
#        0.01297194, 0.01196983, 0.01013865, 0.00940064, 0.00922935,
#        0.00848709, 0.00816389, 0.00759101, 0.00663953, 0.00631507,
#        0.00601554, 0.00580178, 0.00559512, 0.00549241, 0.00498594,
#        0.00464956, 0.00457252, 0.00454964, 0.00430301, 0.0041996 ,
#        0.00409504, 0.00399244, 0.00391926, 0.00378031, 0.00365852,
#        0.00359251, 0.00347922, 0.00345658, 0.00339881, 0.00333328,
#        0.00318786, 0.00308828, 0.00302721, 0.00292783, 0.00292317,
#        0.00287278, 0.00270831, 0.00268501, 0.00266238, 0.00260311])

# %%
#visualize PCA plot
plt.figure(figsize=(8,6))
sns.scatterplot(x="PC1", y="PC2", hue="cancer_type", data=pca_df, palette="viridis")
plt.xlabel("PC 1")
plt.ylabel("PC 2")
plt.title("PCA of Gene Counts subset on 5000 Highly Variable Genes")
plt.legend()
plt.show()

# %% [markdown]
# Given the variance explained by each PC is very low, we don't see any clear clustering with PCA. Next, we applied TSNE to try non-linear DR

# %%
tsne = TSNE(n_components=2)
tsne_obj = tsne.fit_transform(X_hvg.values)

tsne_df = pd.DataFrame(tsne_obj, columns=["tSNE1", "tSNE2"])
tsne_df["cancer_type"] = smote_df["cancer_type"].values

#visualize t-SNE plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x="tSNE1", y="tSNE2", hue="cancer_type", data=tsne_df, palette="viridis", alpha=0.8)
plt.title("tSNE of Gene Counts subset on 5000 Highly Variable Genes")
plt.xlabel("tSNE 1")
plt.ylabel("tSNE 2")
plt.legend(title="Cancer Type")
plt.show()

# %% [markdown]
# We see much better clustering with tSNE compared with PCA.

# %% [markdown]
# ## Support Vector Classifier Model Fitting

# %%
#create train and test datasets
X_train, X_test, y_train, y_test = train_test_split(X_pca, y_hvg, test_size=0.2, random_state=42, stratify=y_hvg)

# %%
#train and fit the SVC with radial kernel
svm = SVC(kernel="rbf", C=1, random_state=42)
svm.fit(X_train, y_train)
# Out:
# SVC(C=1, random_state=42)

# %%
y_pred = svm.predict(X_test)

# %% [markdown]
# ## Metrics and Evaluation

# %%
#with 5k HVGs
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

f1 = f1_score(y_test, y_pred, average='macro')
print(f"Macro F1 Score: {f1:.4f}")

bal_acc = balanced_accuracy_score(y_test, y_pred)
print(f"Balanced Accuracy: {bal_acc:.4f}")

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9492
# Macro F1 Score: 0.9492
# Balanced Accuracy: 0.9492
#               precision    recall  f1-score   support
#
#         BLCA       0.91      0.93      0.92       121
#         CESC       0.91      0.92      0.91       121
#          GBM       1.00      0.99      1.00       121
#         HNSC       0.91      0.89      0.90       122
#         KIRC       0.98      0.98      0.98       122
#          LGG       0.98      0.98      0.98       121
#
#     accuracy                           0.95       728
#    macro avg       0.95      0.95      0.95       728
# weighted avg       0.95      0.95      0.95       728

# %% [markdown]
# We can see from the above evaluation, the model achieves a 94.51% accuracy with overall macro F1 score of 0.95.

# %%
#confusion matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="viridis", xticklabels=np.unique(y_pred), yticklabels=np.unique(y_test))
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix for Classifying Cancer Types")
plt.show()

# %%
#create one-hot encoding for multi-class labels
y_bin = label_binarize(y_train, classes=np.unique(y_train))
class_labels = np.unique(y_train)
n_classes = y_bin.shape[1]

#use SVC to get probability scores for each class
svm = OneVsRestClassifier(SVC(kernel="rbf", C=1, probability=True, random_state=42))
svm.fit(X_train, y_bin)

y_score = svm.predict_proba(X_test)
y_test_bin = label_binarize(y_test, classes=class_labels)

#visualize
plt.figure(figsize=(8, 6))

for i, label in enumerate(class_labels):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{label} (AUC = {roc_auc:.2f})")

#reference line
plt.plot([0, 1], [0, 1], "k--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("One-vs-Rest Multiclass ROC Curve")
plt.legend(title="Class Labels")
plt.grid()
plt.show()

# %% [markdown]
# ## Comparative analysis of hyperparameters

# %% [markdown]
# We also performed hyperparameter tuning for different values of hyperparameters
# - **number of highly variable genes selected** - more genes, more accurate classification but takes more time. less genes, faster but effects accuracy.
# - **regularization parameter C in SVC** - uses squared L2 penalty. C is inversely proportional to the strength of the regularization. So, smaller C means larger penalty leading to better generalization and larger C means smaller penalty leading to overfitting

# %%
#different number of HVGs
hvg = [500, 1000, 2000, 5000, 7500, 10000]
results = []

for n in hvg:
    top_genes = X_smote.var(axis=0).nlargest(n).index 

    X_hvg = X_smote[top_genes]
    y_hvg = y_smote.values[:, 0]

    pca = PCA(n_components=50)
    X_pca = pca.fit_transform(X_hvg)

    X_train, X_test, y_train, y_test = train_test_split(X_pca, y_hvg, test_size=0.2, random_state=42, stratify=y_hvg)

    svm_model = SVC(kernel="rbf", C=1, random_state=42)
    svm_model.fit(X_train, y_train)
    y_pred = svm_model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='macro')
    results.append([n, accuracy, f1])

results_df = pd.DataFrame(results, columns=["# HVG", "Accuracy", "F1_Score"])

print("\nComparison of SVM Performance with PCA:")
print(results_df)

#visualize
plt.figure(figsize=(8, 5))
plt.plot(results_df["# HVG"], results_df["Accuracy"], marker="o", label="Accuracy")
plt.plot(results_df["# HVG"], results_df["F1_Score"], marker="s", label="F1 Score")
plt.xlabel("Number of Highly Variable Genes")
plt.ylabel("Score")
plt.title("SVM Performance for Different Numbers of Highly Variable Genes")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Comparison of SVM Performance with PCA:
#    # HVG  Accuracy  F1_Score
# 0    500  0.907967  0.908354
# 1   1000  0.927198  0.927115
# 2   2000  0.938187  0.938202
# 3   5000  0.945055  0.945191
# 4   7500  0.949176  0.949215
# 5  10000  0.957418  0.957444

# %% [markdown]
# As we can see, adding more features increases the accuracy of the model but takes more time for training.

# %%
#different C values to test
C_values = [0.01, 0.1, 1, 10, 100]
results = []

top_genes = X_smote.var(axis=0).nlargest(5000).index

X_hvg = X_smote[top_genes]
y_hvg = y_smote.values[:, 0]

pca = PCA(n_components=50)
X_pca = pca.fit_transform(X_hvg)

X_train, X_test, y_train, y_test = train_test_split(X_pca, y_hvg, test_size=0.2, random_state=42, stratify=y_hvg)

for c in C_values:
    svm_model = SVC(kernel="rbf", C=c, random_state=42)
    svm_model.fit(X_train, y_train)
    y_pred = svm_model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='macro')
    results.append([c, accuracy, f1])

results_df = pd.DataFrame(results, columns=["C_Value", "Accuracy", "F1_Score"])
print(results_df)

#visualize
plt.figure(figsize=(8, 5))
plt.plot(results_df["C_Value"], results_df["Accuracy"], marker="o", label="Accuracy")
plt.plot(results_df["C_Value"], results_df["F1_Score"], marker="s", label="F1 Score")
plt.xscale("log")
plt.xlabel("C Value (Log Scale)")
plt.ylabel("Score")
plt.title(f"SVM Performance with Different C Values with 5000 HVGs")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#    C_Value  Accuracy  F1_Score
# 0     0.01  0.421703  0.351682
# 1     0.10  0.760989  0.763603
# 2     1.00  0.947802  0.947866
# 3    10.00  0.951923  0.952008
# 4   100.00  0.949176  0.949269

# %% [markdown]
# As we can see from the plot above, from 1, the performance of the model plateaues.
